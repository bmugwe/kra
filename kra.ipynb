# %%
import requests
import time
import pandas as pd


url = "https://etims.kra.go.ke/main/signup/getItaxData"
custome_headers = ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']

# %%
read_data = pd.read_csv('kra/input/kra.csv', )

# %%
read_data
# Out:
#         PIN_NUMBER
# 0      A006435250S
# 1      A001581378W
# 2      A006785630D
# 3      A003265256U
# 4      A003934135V
# ...            ...
# 69800  A015532749W
# 69801  A015660160Z
# 69802  A015716301Z
# 69803  A015826076J
# 69804  A016163545J
#
# [69805 rows x 1 columns]

# %%
def getKRA(tinID):
    payload = "tin=P051889461D"
    headers = {
    'Accept': 'application/json, text/javascript, */*; q=0.01',
    'Accept-Language': 'en-US,en;q=0.9,en-GB;q=0.8',
    'Connection': 'keep-alive',
    'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8',
    'Cookie': 'BIGipServer~k8sprd~ingress_etims-prod_etims-portal=2449595402.36895.0000; JSESSIONID=49F1B18CE4190E06E2F45BA0C7B053A5',
    'DNT': '1',
    'Origin': 'https://etims.kra.go.ke',
    'Referer': 'https://etims.kra.go.ke/main/signup/indexTinUser',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0',
    'X-Requested-With': 'XMLHttpRequest',
    'sec-ch-ua': '"Not/A)Brand";v="8", "Chromium";v="126", "Microsoft Edge";v="126"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Linux"'
    }
    response = requests.request("POST", url, headers=headers, data=payload)
    return response.json()

# %%
def createArray(face):
    pd_base = []
    pd_headers = []
    if(face["base"]):
        base = face['base']
        for i in base:
            pd_base.append(base[i])
            pd_headers.append(i)
            
    print(pd_headers)
    return pd_base

# %%
All_data = []
for pin in read_data['PIN_NUMBER']:
    print(pin)
    face = getKRA("")
    array_data = createArray(face)
    All_data.append(array_data)   
    
    # break
pd.DataFrame(All_data).to_csv("kra/output/kra.csv", header=custom_headers)
# Out:
# A006435250S
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001581378W
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A006785630D
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003265256U
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003934135V
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002529068H
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A009100095I
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A006417350V
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A005674400N
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001631418D
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002907323X
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A005031626Y
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A009118768F
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003258290B
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A011141524Q
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A008257074C
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003841218I
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A007488220W
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001262924H
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003599490R
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003246504J
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002447453Y
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003878241G
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A008903376I
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003112165C
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A005473025K
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002446494F
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002428845A
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001310223S
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003132222S
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001200628Y
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A009821484D
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A005253162M
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002902105H
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003086048Q
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003939119E
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A007555276J
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A004121227S
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A007469726H
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003616207Q
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003889017E
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003282134F
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002740166S
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001189283A
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A004592706R
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A006052083L
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A005730280T
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001615080V
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001617042R
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A010234967T
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A006680382A
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003985737M
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A006546473I
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002802341L
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A006499913D
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001815114L
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003363484W
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A007091962P
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A005127685A
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002425348S
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001344377U
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A010590052J
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002489345D
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001327155S
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A006301542B
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001289968N
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A006944249G
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A007087417Q
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002784213N
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001367112G
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003151030N
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A006803084B
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A005986428M
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A007619481O
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003612528Z
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002196646T
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A004515615Z
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003381878X
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A004628013P
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A005971866I
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002806785N
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A004118953V
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001760091T
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A008077548B
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002724175Z
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A004208083W
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A009568697B
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A008847746Q
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003947969Y
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003371956R
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002227418K
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A007884599Y
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A005460460M
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A007069150V
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A005283109I
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001972080Z
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001124452D
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A006536436A
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003661511C
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A007061166I
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003209883F
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002257561W
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002594225R
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002926430X
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003221657I
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001872128S
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002773822U
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002518175E
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A010417451Q
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003268902R
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A006154773T
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A006128026K
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A008138360U
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A007263366V
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A007080398V
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001610002T
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A008235875F
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002471958U
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003480336J
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003182040X
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002903184A
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A008400779X
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003092142C
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002509716V
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002797533G
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003035455Z
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A007672817V
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002452890W
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003132894Q
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002204667Q
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A009177553A
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A010997865U
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002618076G
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001202318U
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002711779Z
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003974143Z
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A006425459C
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002306071Z
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003159386D
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002478414R
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002655141S
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001591724L
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001178287B
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002777817E
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A004487024T
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A009823472G
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003174250G
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A001198076Y
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003401614U
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A010003207P
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A008586638L
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A004035649R
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A003592678H
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A008039068C
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# A002958308F
# ...
# P051502507S
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# P051409184P
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# P051230994E
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# P051741388M
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# P051559738W
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# P051216518V
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# P051216518V
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# P051097014S
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# P051196275J
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# P051372958K
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# P051585214B
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# P051431712I
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# P051568801J
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# P051373106Q
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# P051301875Y
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# P051632732A
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# P051808397E
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# P051708023F
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# P051415706Y
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# P051422684G
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# P051553060B
# ['ebmTyCd', 'modrId', 'modrNm', 'modDt', 'tin', 'taxpr_nm', 'in_itax', 'taxpr_stts_cd', 'taxpr_ty_cd', 'bsns_actv', 'prvnc_no', 'dstrt_no', 'sctr_no', 'loc_desc', 'tel_no', 'email', 'sync_dt', 'vat_ty_cd', 'nid', 'taxpr_no', 'bsns_yn', 'remarks', 'regr_id', 'regr_nm', 'reg_dt', 'tso_id', 'ismri']
# P051709661V
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:383, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382 try:
# --> 383     self._validate_conn(conn)
#     384 except (SocketTimeout, BaseSSLError) as e:
#     385     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:1017, in HTTPSConnectionPool._validate_conn(self, conn)
#    1016 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1017     conn.connect()
#    1019 if not conn.is_verified:
#
# File /usr/lib/python3/dist-packages/urllib3/connection.py:411, in HTTPSConnection.connect(self)
#     409     context.load_default_certs()
# --> 411 self.sock = ssl_wrap_socket(
#     412     sock=conn,
#     413     keyfile=self.key_file,
#     414     certfile=self.cert_file,
#     415     key_password=self.key_password,
#     416     ca_certs=self.ca_certs,
#     417     ca_cert_dir=self.ca_cert_dir,
#     418     ca_cert_data=self.ca_cert_data,
#     419     server_hostname=server_hostname,
#     420     ssl_context=context,
#     421     tls_in_tls=tls_in_tls,
#     422 )
#     424 # If we're using all defaults and the connection
#     425 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     426 # for the host.
#
# File /usr/lib/python3/dist-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#
# File /usr/lib/python3/dist-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#
# File /usr/lib/python3.10/ssl.py:513, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     507 def wrap_socket(self, sock, server_side=False,
#     508                 do_handshake_on_connect=True,
#     509                 suppress_ragged_eofs=True,
#     510                 server_hostname=None, session=None):
#     511     # SSLSocket class handles server_hostname encoding before it calls
#     512     # ctx._wrap_socket()
# --> 513     return self.sslsocket_class._create(
#     514         sock=sock,
#     515         server_side=server_side,
#     516         do_handshake_on_connect=do_handshake_on_connect,
#     517         suppress_ragged_eofs=suppress_ragged_eofs,
#     518         server_hostname=server_hostname,
#     519         context=self,
#     520         session=session
#     521     )
#
# File /usr/lib/python3.10/ssl.py:1100, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1099             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1100         self.do_handshake()
#    1101 except (OSError, ValueError):
#
# File /usr/lib/python3.10/ssl.py:1371, in SSLSocket.do_handshake(self, block)
#    1370         self.settimeout(None)
# -> 1371     self._sslobj.do_handshake()
#    1372 finally:
#
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/requests/adapters.py:439, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 if not chunked:
# --> 439     resp = conn.urlopen(
#     440         method=request.method,
#     441         url=url,
#     442         body=request.body,
#     443         headers=request.headers,
#     444         redirect=False,
#     445         assert_same_host=False,
#     446         preload_content=False,
#     447         decode_content=False,
#     448         retries=self.max_retries,
#     449         timeout=timeout
#     450     )
#     452 # Send the request.
#     453 else:
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:756, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754     e = ProtocolError("Connection aborted.", e)
# --> 756 retries = retries.increment(
#     757     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     758 )
#     759 retries.sleep()
#
# File /usr/lib/python3/dist-packages/urllib3/util/retry.py:532, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     531 if read is False or not self._is_method_retryable(method):
# --> 532     raise six.reraise(type(error), error, _stacktrace)
#     533 elif read is not None:
#
# File /usr/lib/python3/dist-packages/six.py:719, in reraise(tp, value, tb)
#     718         raise value.with_traceback(tb)
# --> 719     raise value
#     720 finally:
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:700, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     699 # Make the request on the httplib connection object.
# --> 700 httplib_response = self._make_request(
#     701     conn,
#     702     method,
#     703     url,
#     704     timeout=timeout_obj,
#     705     body=body,
#     706     headers=headers,
#     707     chunked=chunked,
#     708 )
#     710 # If we're going to release the connection in ``finally:``, then
#     711 # the response doesn't need to know about the connection. Otherwise
#     712 # it will also try to release it and we'll have a double-release
#     713 # mess.
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 except (SocketTimeout, BaseSSLError) as e:
#     385     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
# --> 386     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#     387     raise
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:337, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     336 if isinstance(err, SocketTimeout):
# --> 337     raise ReadTimeoutError(
#     338         self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     339     )
#     341 # See the above comment about EAGAIN in Python 3. In Python 2 we have
#     342 # to specifically catch it and throw the timeout error
#
# ReadTimeoutError: HTTPSConnectionPool(host='etims.kra.go.ke', port=443): Read timed out. (read timeout=None)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[49], line 4
#       2 for pin in read_data['PIN_NUMBER']:
#       3     print(pin)
# ----> 4     face = getKRA("")
#       5     array_data = createArray(face)
#       6     All_data.append(array_data)
#
# Cell In[24], line 21, in getKRA(tinID)
#       2 payload = "tin=P051889461D"
#       3 headers = {
#       4 'Accept': 'application/json, text/javascript, */*; q=0.01',
#       5 'Accept-Language': 'en-US,en;q=0.9,en-GB;q=0.8',
#    (...)
#      19 'sec-ch-ua-platform': '"Linux"'
#      20 }
# ---> 21 response = requests.request("POST", url, headers=headers, data=payload)
#      22 return response.json()
#
# File /usr/lib/python3/dist-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:544, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     539 send_kwargs = {
#     540     'timeout': timeout,
#     541     'allow_redirects': allow_redirects,
#     542 }
#     543 send_kwargs.update(settings)
# --> 544 resp = self.send(prep, **send_kwargs)
#     546 return resp
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:657, in Session.send(self, request, **kwargs)
#     654 start = preferred_clock()
#     656 # Send the request
# --> 657 r = adapter.send(request, **kwargs)
#     659 # Total elapsed time of the request (approximately)
#     660 elapsed = preferred_clock() - start
#
# File /usr/lib/python3/dist-packages/requests/adapters.py:529, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     527     raise SSLError(e, request=request)
#     528 elif isinstance(e, ReadTimeoutError):
# --> 529     raise ReadTimeout(e, request=request)
#     530 else:
#     531     raise
#
# ReadTimeout: HTTPSConnectionPool(host='etims.kra.go.ke', port=443): Read timed out. (read timeout=None)
